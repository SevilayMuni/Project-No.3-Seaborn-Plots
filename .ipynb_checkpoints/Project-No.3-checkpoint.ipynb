# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns 
from sklearn.impute import KNNImputer, SimpleImputer

# %%
thyroid_df = pd.read_csv("Thyroid_Diff.csv", delimiter = ',')
thyroid_df
# Out:
#      Age Gender Smoking Hx Smoking Hx Radiothreapy          Thyroid Function  \
# 0     27      F      No         No              No                 Euthyroid
# 1     34      F      No        Yes              No                 Euthyroid
# 2     30      F      No         No              No                 Euthyroid
# 3     62      F      No         No              No                 Euthyroid
# 4     62      F      No         No              No                 Euthyroid
# ..   ...    ...     ...        ...             ...                       ...
# 378   72      M     Yes        Yes             Yes                 Euthyroid
# 379   81      M     Yes         No             Yes                 Euthyroid
# 380   72      M     Yes        Yes              No                 Euthyroid
# 381   61      M     Yes        Yes             Yes  Clinical Hyperthyroidism
# 382   67      M     Yes         No              No                 Euthyroid
#
# ...

# %%
thyroid_df.head(10)
# Out:
#    Age Gender Smoking Hx Smoking Hx Radiothreapy          Thyroid Function  \
# 0   27      F      No         No              No                 Euthyroid
# 1   34      F      No        Yes              No                 Euthyroid
# 2   30      F      No         No              No                 Euthyroid
# 3   62      F      No         No              No                 Euthyroid
# 4   62      F      No         No              No                 Euthyroid
# 5   52      M     Yes         No              No                 Euthyroid
# 6   41      F      No        Yes              No  Clinical Hyperthyroidism
# 7   46      F      No         No              No                 Euthyroid
# 8   51      F      No         No              No                 Euthyroid
# 9   40      F      No         No              No                 Euthyroid
#
#           Physical Examination Adenopathy       Pathology     Focality Risk  \
# ...

# %%
thyroid_df.describe()
# Out:
#               Age
# count  383.000000
# mean    40.866841
# std     15.134494
# min     15.000000
# 25%     29.000000
# 50%     37.000000
# 75%     51.000000
# max     82.000000

# %%
thyroid_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 383 entries, 0 to 382
# Data columns (total 17 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Age                   383 non-null    int64
#  1   Gender                383 non-null    object
#  2   Smoking               383 non-null    object
#  3   Hx Smoking            383 non-null    object
#  4   Hx Radiothreapy       383 non-null    object
#  5   Thyroid Function      383 non-null    object
#  6   Physical Examination  383 non-null    object
#  7   Adenopathy            383 non-null    object
#  8   Pathology             383 non-null    object
#  9   Focality              383 non-null    object
#  10  Risk                  383 non-null    object
#  11  T                     383 non-null    object
#  12  N                     383 non-null    object
#  13  M                     383 non-null    object
#  14  Stage                 383 non-null    object
# ...

# %%
# Renaming column names
thyroid_df = thyroid_df.rename(columns={'Hx Smoking': 'Smoking History',
                   'Hx Radiothreapy': 'Radiotherapy History',
                   'Pathology': 'Thyroid Cancer Type/Pathology',
                   'T': 'Tumor',
                   'N': 'Lymph Nodes',
                   'M': 'Metastasis',
                  'Response' : 'Response to Treatment'})
thyroid_df
# Out:
#      Age Gender Smoking Smoking History Radiotherapy History  \
# 0     27      F      No              No                   No
# 1     34      F      No             Yes                   No
# 2     30      F      No              No                   No
# 3     62      F      No              No                   No
# 4     62      F      No              No                   No
# ..   ...    ...     ...             ...                  ...
# 378   72      M     Yes             Yes                  Yes
# 379   81      M     Yes              No                  Yes
# 380   72      M     Yes             Yes                   No
# 381   61      M     Yes             Yes                  Yes
# 382   67      M     Yes              No                   No
#
#              Thyroid Function         Physical Examination Adenopathy  \
# 0                   Euthyroid   Single nodular goiter-left         No
# 1                   Euthyroid          Multinodular goiter         No
# ...

# %%
# Smoking History: whether individuals have a history of smoking (Yes or No).
# Radiotherapy History: whether individuals have radiotherapy treatment history (Yes or No).
# Thyroid Function: thyroid gland status or function.
# Physical Examination: Describes the results of a physical examination, likely related to the thyroid.
# Adenopathy: presence and location of adenopathy (enlarged lymph nodes).

# Thyroid Cancer Pathology: Describes the types of thyroid cancer based on pathology examinations, 
#including specific subtypes like "Micropapillary Papillary," "Follicular," and "Hürthle cell."

# Focality: whether the thyroid cancer is unifocal or multifocal.
# Risk: risk category associated with thyroid cancer.
# Tumor: stage of thyroid cancer, indicating the size and extent of the primary tumor.

# Lymph Nodes: indicating the involvement of nearby lymph nodes.
# Metastasis: whether the cancer has spread to distant organs.
# Stage: Represents the overall stage of thyroid cancer based on T, N, and M stage combination.

# Treatment Response: Describes treatment response 
# Categories; 'Indeterminate,' 'Excellent,' 'Structural Incomplete,' and 'Biochemical Incomplete.' 
# Recurred: Indicates whether thyroid cancer has recurred (e.g., Yes or No).

# %%
# Replace values with clearer inputs
thyroid_df['Adenopathy'] = thyroid_df['Adenopathy'].replace({'No' : 'No Lympth Adenopathy' ,
                          'Left' : 'Left Side Body Adenopathy' ,
                          'Right' : 'Right Side Body Adenopathy' ,
                          'Extensive' : 'Extensive and Widespread Adenopathy'})
thyroid_df
# Out:
#      Age Gender Smoking Smoking History Radiotherapy History  \
# 0     27      F      No              No                   No
# 1     34      F      No             Yes                   No
# 2     30      F      No              No                   No
# 3     62      F      No              No                   No
# 4     62      F      No              No                   No
# ..   ...    ...     ...             ...                  ...
# 378   72      M     Yes             Yes                  Yes
# 379   81      M     Yes              No                  Yes
# 380   72      M     Yes             Yes                   No
# 381   61      M     Yes             Yes                  Yes
# 382   67      M     Yes              No                   No
#
#              Thyroid Function         Physical Examination  \
# 0                   Euthyroid   Single nodular goiter-left
# 1                   Euthyroid          Multinodular goiter
# ...

# %%
thyroid_df['Stage'] = thyroid_df['Stage'].replace({'I' : 'First-Stage' , 'II' : 'Second-Stage' , 'III' : 'Third-Stage'})

thyroid_df['Tumor'] = thyroid_df['Tumor'].replace({'T1a' : '1 cm or smaller', 
                             'T1b' : 'larger than 1 cm but smaller than 2 cm', 
                             'T2' : 'larger than 2 cm but smaller than 4 cm', 
                             'T3a' : 'larger than 4 cm',
                             'T3b' : ' grown outside the thyroid',
                             'T4a' : 'invaded nearby structures', 
                             'T4b' : 'invaded nearby structures'})

thyroid_df['Lymph Nodes'] = thyroid_df['Lymph Nodes'].replace({'N0' : 'no regional lymph node metastasis',
                                                               'N1b' : 'regional lymph node metastasis in the neck center',
                                                               'N1a' : 'regional lymph node metastasis in the neck lateral'})

thyroid_df['Metastasis'] = thyroid_df['Metastasis'].replace({'M0': 'no distant metastasis', 
                                                             'M1' : 'distant metastasis'})
thyroid_df
# Out:
#      Age Gender Smoking Smoking History Radiotherapy History  \
# 0     27      F      No              No                   No
# 1     34      F      No             Yes                   No
# 2     30      F      No              No                   No
# 3     62      F      No              No                   No
# 4     62      F      No              No                   No
# ..   ...    ...     ...             ...                  ...
# 378   72      M     Yes             Yes                  Yes
# 379   81      M     Yes              No                  Yes
# 380   72      M     Yes             Yes                   No
# 381   61      M     Yes             Yes                  Yes
# 382   67      M     Yes              No                   No
#
#              Thyroid Function         Physical Examination  \
# 0                   Euthyroid   Single nodular goiter-left
# 1                   Euthyroid          Multinodular goiter
# ...

# %%
thyroid_df.to_csv("Thyroid-Cancer-Preprocessed.csv", sep = ',', index = False)

# %%
# Creating boxplot to explore the df

# 1x2 grid for the plots
fig, axes = plt.subplots(1, 2, figsize=(20, 8))

# Tumor Boxplot
sns.boxplot(x = 'Tumor', y = 'Age', data = thyroid_df, palette = "rocket_r", ax = axes[0])
axes[0].set_title('Age by Tumor Stage', fontsize = 16, fontweight = 'bold') 
axes[0].set_xlabel('Tumor Stage', fontsize = 14, fontweight = 'bold')
axes[0].set_ylabel('Age', fontsize = 14, fontweight = 'bold', labelpad = 20)
axes[0].tick_params(axis = 'x', rotation = 55)

# Stage Boxplot 
sns.boxplot(x = 'Stage', y = 'Age', data = thyroid_df, palette = "flare", ax = axes[1])
axes[1].set_title('Age by Cancer Stage', fontsize = 16, fontweight = 'bold')
axes[1].set_xlabel('Cancer Stage', fontsize = 14, fontweight = 'bold', labelpad = 20)
axes[1].set_ylabel('Age', fontsize = 14, fontweight = 'bold', labelpad = 20)
axes[1].tick_params(axis = 'x', rotation = 0)
sns.despine()
plt.savefig("Tumor-and-Cancer-Stage-Box-Plots.png", dpi = 300, bbox_inches = 'tight')
plt.show()

# %%
def map_risk(risk):
    if risk == 'Low':
        return 1
    elif risk == 'Intermediate':
        return 2
    else:
        return 3

# New column with defined function
thyroid_df['Risk Level'] = thyroid_df['Risk'].apply(map_risk)
thyroid_df
# Out:
#      Age Gender Smoking Smoking History Radiotherapy History  \
# 0     27      F      No              No                   No
# 1     34      F      No             Yes                   No
# 2     30      F      No              No                   No
# 3     62      F      No              No                   No
# 4     62      F      No              No                   No
# ..   ...    ...     ...             ...                  ...
# 378   72      M     Yes             Yes                  Yes
# 379   81      M     Yes              No                  Yes
# 380   72      M     Yes             Yes                   No
# 381   61      M     Yes             Yes                  Yes
# 382   67      M     Yes              No                   No
#
#              Thyroid Function         Physical Examination  \
# 0                   Euthyroid   Single nodular goiter-left
# 1                   Euthyroid          Multinodular goiter
# ...

# %%
sns.set_palette("coolwarm")
fig, axes = plt.subplots(1, 2, figsize=(20, 8))

#  Risk Pie chart
risk_level = thyroid_df['Risk'].value_counts()
risk_level.plot(kind = 'pie', autopct='%0.2f%%', explode = [0.05, 0.08, 0.1], 
           labels = risk_level.index, textprops = {'fontsize': 14}, shadow = True, ax = axes[0])
axes[0].set_title('Risk Level Distribution', fontsize = 15, fontweight = 'bold')
axes[0].set_ylabel('')

# Stage Pie chart
cancer_stage = thyroid_df['Stage'].value_counts()
cancer_stage.plot(kind = 'pie', autopct='%0.2f%%', 
                  labels = cancer_stage.index, textprops = {'fontsize': 14}, explode = [0.1, 0.2, 0.3, 0.4, 0.9], shadow = True, ax = axes[1])
axes[1].set_title('Cancer Stage Distribution', fontsize = 15, fontweight = 'bold')
axes[1].set_ylabel('')

plt.savefig("Risk-Level-and-Cancer-Stage-Distributions.png", dpi = 300, bbox_inches = 'tight')
plt.show()

# %%
thyroid_df['Metastasis'].unique()
# Out:
# array(['no distant metastasis', 'distant metastasis'], dtype=object)

# %%
sns.set_palette("coolwarm")
fig, axes = plt.subplots(1, 2, figsize=(20, 8))

# Metastasis Pie chart
metastasis = thyroid_df['Metastasis'].value_counts()
metastasis.plot(kind = 'pie', autopct='%0.2f%%', explode = [0.1, 0.3], 
           labels = metastasis.index, textprops = {'fontsize': 14}, shadow = True, ax = axes[0])
axes[0].set_title('Metastasis Distribution', fontsize = 15, fontweight = 'bold')
axes[0].set_ylabel('')

# Thyroid Cancer Type/Pathology Pie chart
pathology = thyroid_df['Thyroid Cancer Type/Pathology'].value_counts()
pathology.plot(kind = 'pie', autopct='%0.2f%%', 
                  labels = pathology.index, textprops = {'fontsize': 14}, 
               explode = [0.1, 0.2, 0.3, 0.5], shadow = True, ax = axes[1])
axes[1].set_title('Thyroid Cancer Pathology Distribution', fontsize = 15, fontweight = 'bold')
axes[1].set_ylabel('')
plt.savefig("Metastasis-and-Pathology-Distributions.png", dpi = 300, bbox_inches = 'tight')
plt.show()

# %%
# Age Histogram
plt.figure(figsize = (10, 6))
sns.histplot(thyroid_df['Age'], bins = 20, kde = True, color = '#AAB7B8')
plt.xlabel('Age', fontsize = 13, fontweight = 'bold', labelpad = 20)
plt.ylabel('Frequency', fontsize = 13, fontweight = 'bold', labelpad = 20)
plt.title('Age Distribution', fontsize = 15, fontweight = 'bold', pad = 20)
sns.despine()
plt.savefig("Histogram-Age-Distribution.png", dpi = 300, bbox_inches = 'tight')
plt.show()

# %%
# The counts of patients in each selected category

fig, axes = plt.subplots(1, 3, figsize=(20, 8))


sns.countplot(x = 'Gender', data = thyroid_df, palette = 'Paired', width = 0.35, ax = axes[0])
axes[0].set_title('Gender Distribution', fontsize = 17, fontweight = 'bold', pad = 25)
axes[0].set_xlabel('Gender', fontsize = 15, fontweight = 'bold', labelpad = 25)
axes[0].set_ylabel('Count', fontsize = 15, fontweight = 'bold', labelpad = 25)
axes[0].tick_params(axis = 'x',  size = 10, labelsize = 15, rotation = 0)
axes[0].tick_params(axis = 'y',  size = 10, labelsize = 12, rotation = 0)

sns.countplot(x = 'Smoking', data = thyroid_df, palette = 'Paired', width = 0.35, ax = axes[1])
axes[1].set_title('Smoking Distribution', fontsize = 17, fontweight = 'bold', pad = 25)
axes[1].set_xlabel('Smoking', fontsize = 15, fontweight = 'bold', labelpad = 25)
axes[1].set_ylabel('Count', fontsize = 15, fontweight = 'bold', labelpad = 25)
axes[1].tick_params(axis = 'x',  size = 10, labelsize = 15, rotation = 0)
axes[1].tick_params(axis = 'y',  size = 10, labelsize = 12, rotation = 0)

sns.countplot(x = 'Metastasis', data = thyroid_df, palette = 'Paired', width = 0.35, ax = axes[2])
axes[2].set_title('Metastasis Distribution', fontsize = 17, fontweight = 'bold', pad = 25)
axes[2].set_xlabel('Metastasis', fontsize = 15, fontweight = 'bold', labelpad = 25)
axes[2].set_ylabel('Count', fontsize = 15, fontweight = 'bold', labelpad = 25)
axes[2].tick_params(axis = 'x',  size = 10, labelsize = 14, rotation = 0)
axes[2].tick_params(axis = 'y',  size = 10, labelsize = 12, rotation = 0)
sns.despine()
plt.savefig("Gender-Smoking-Metastasis-Counts-BarGraph.png", dpi = 300, bbox_inches = 'tight')
plt.show()

# %%
# The counts of patients in each selected category

fig, axes = plt.subplots(1, 3, figsize=(20, 8))

sns.countplot(x = 'Radiotherapy History', data = thyroid_df, palette = 'Paired', width = 0.35,  ax = axes[0])
axes[0].set_title('Radiotherapy History Distribution', fontsize = 17, fontweight = 'bold', pad = 25)
axes[0].set_xlabel('Radiotherapy', fontsize = 15, fontweight = 'bold', labelpad = 25)
axes[0].set_ylabel('Count', fontsize = 15, fontweight = 'bold', labelpad = 25)
axes[0].tick_params(axis = 'x',  size = 10, labelsize = 14, rotation = 0)
axes[0].tick_params(axis = 'y',  size = 10, labelsize = 12, rotation = 0)

sns.countplot(x = 'Response to Treatment', data = thyroid_df, palette = 'Paired', width = 0.55,  ax = axes[1])
axes[1].set_title('Distribution of Treatment Response', fontsize = 17, fontweight = 'bold', pad = 25)
axes[1].set_xlabel('Treatment Response', fontsize = 15, fontweight = 'bold', labelpad = 25)
axes[1].set_ylabel('Count', fontsize = 15, fontweight = 'bold', labelpad = 25)
axes[1].tick_params(axis = 'x', size = 10, labelsize = 13, rotation = 35)
axes[1].tick_params(axis = 'y', size = 10, labelsize = 12, rotation = 35)

sns.countplot(x = 'Recurred', data = thyroid_df, palette = 'Paired', width = 0.35, ax = axes[2])
axes[2].set_title('Distribution of Recurrence', fontsize = 17, fontweight = 'bold', pad = 25)
axes[2].set_xlabel('Recurrence', fontsize = 15, fontweight = 'bold', labelpad = 25)
axes[2].set_ylabel('Count', fontsize = 15, fontweight = 'bold', labelpad = 25)
axes[2].tick_params(axis = 'x',  size = 10, labelsize = 14, rotation = 0)
axes[2].tick_params(axis = 'y',  size = 10, labelsize = 12, rotation = 0)
sns.despine()
plt.savefig("Radiotherapy-TreatmentResponse-Recurrence-Counts-BarGraph.png", dpi = 300, bbox_inches = 'tight')
plt.show()

# %%
# Swarm Plot of age distribution based on adenopathy presence and location

plt.figure(figsize=(22, 11))

sns.swarmplot(x = 'Adenopathy', y = 'Age', data = thyroid_df, palette = 'flare', size = 10, 
              hue = 'Adenopathy', dodge = False)
plt.title('Age Distribution based on Adenopathy', fontsize = 18, fontweight = 'bold', pad = 30)
plt.xlabel('Adenopathy', fontsize = 15, fontweight = 'bold', labelpad = 25)
plt.ylabel('Age', fontsize = 15, fontweight = 'bold', labelpad = 25)
plt.xticks(rotation = 30, size = 13)
plt.yticks(size = 13)
plt.legend(title = 'Adenopathy', bbox_to_anchor = (1.05, 1), loc = 'upper left', 
           fontsize = 'x-large', markerscale = 2, title_fontsize = 'xx-large')
sns.despine()
plt.savefig("Age-vs-Adenopathy-SwarmPlot.png", dpi = 300, bbox_inches = 'tight')
plt.show()

# %%
plt.figure(figsize=(14, 8))

sns.violinplot(x = 'Risk Level', y = 'Age', data = thyroid_df, palette = 'flare', 
               width = 0.65, inner = 'quartile')
plt.title('Age Distribution by Risk Level', fontsize = 17, fontweight = 'bold', pad = 25)
plt.xlabel('Risk Level', fontsize = 15, fontweight = 'bold', labelpad = 25)
plt.ylabel('Age', fontsize = 15, fontweight = 'bold', labelpad = 25)
plt.tick_params(axis = 'x',  size = 10, labelsize = 12, rotation = 0)
plt.tick_params(axis = 'y',  size = 10, labelsize = 12, rotation = 0)
sns.despine()
plt.savefig("Age-vs-RiskLevel-Quartile.png", dpi = 300, bbox_inches = 'tight')
plt.show()
